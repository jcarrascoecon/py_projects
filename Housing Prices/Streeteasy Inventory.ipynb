# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
inven = pd.read_csv("rentalInventory_All.csv")
price = pd.read_csv('medianAskingRent_All.csv')

# %%
def reshape(x):
    x = x.set_index('areaName')
    x = x.T
    x = x.drop(['Borough','areaType'])
    return x

# %%
inven = reshape(inven)
price = reshape(price)

# %%
def plot_price(x):
    plt.plot(df[x])
    plt.xlabel('Time')
    plt.ylabel('Median Asking Price')
    plt.show()
    return

plot_price('East Village')

# %%
master = pd.merge(inven, price, on = 'areaName')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-e60807cbc3b8> in <module>
# ----> 1 master = pd.merge(inven, price, on = 'areaName')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
# ...

# %%
# Out:
# areaName All Downtown All Midtown All Upper East Side All Upper Manhattan  \
# 2010-01          4268        3065                2550                 848
# 2010-02          4531        3207                2653                 844
# 2010-03          4599        3242                2641                 813
# 2010-04          4694        3415                2589                 738
# 2010-05          4504        3120                2500                 709
# ...               ...         ...                 ...                 ...
# 2020-01          4669        3720                2040                2054
# 2020-02          4361        3372                1817                1837
# 2020-03          4215        3015                1710                1661
# 2020-04          4436        2995                1602                1386
# 2020-05          7730        4283                2602                2227
#
# areaName All Upper West Side Astoria Auburndale Bath Beach Battery Park City  \
# ...
