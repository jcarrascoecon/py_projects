# %%
import numpy as np
import matplotlib as plt

r = 0.025
T = 50
b = np.empty(T+1)
b[0] = 1000

for t in range(T):
    b[t+1] = b[t] * (1 + r)

plt.plot(b, label = "value")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2904a21679c4> in <module>
#      10     b[t+1] = b[t] * (1 + r)
#      11
# ---> 12 plt.plot(b, label = "value")
#      13 plt.legend()
#      14 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as plt

r = 0.025
T = 50
b = np.empty(T+1)
b[0] = 1000

for t in range(T):
    b[t+1] = b[t] * (1 + r)

plt.plot(b, label='bank balance')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-983a6f63824f> in <module>
#      10     b[t+1] = b[t] * (1 + r)
#      11
# ---> 12 plt.plot(b, label='bank balance')
#      13 plt.legend()
#      14 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
# !pip3 update matplotlib
# Out:
# ERROR: unknown command "update"

# %%
import numpy as np
import matplotlib as plt

ϵ_values = np.random.randn(100)
plt.plot(ϵ_values)
plt.show()

r = 0.025
T = 50
b = np.empty(T+1)
b[0] = 1000

for t in range(T):
    b[t+1] = b[t] * (1 + r)

plt.plot(b, label='bank balance')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c21fd05220fe> in <module>
#       3
#       4 ϵ_values = np.random.randn(100)
# ----> 5 plt.plot(ϵ_values)
#       6 plt.show()
#       7
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
import numpy as np
import matplotlib.pyplot as plt

ϵ_values = np.random.randn(100)
plt.plot(ϵ_values)
plt.show()

r = 0.025
T = 50
b = np.empty(T+1)
b[0] = 1000

for t in range(T):
    b[t+1] = b[t] * (1 + r)

plt.plot(b, label='bank balance')
plt.legend()
plt.show()

# %%
T = 100
eta = []

for t in range(T):
    e = np.random.randn()
    eta.append(e)

plt.plot(eta)
plt.show()

# %%
T = 100
eta = []
t = 0

while t < T:
    e = np.random.randn()
    eta.append(e)
    t = t + 1

plt.plot(eta)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 200
alphas = [0,0.8,0.98]


for alpha in alphas:
    x = np.empty(200)
    x[0] = 0
    for i in range(T-1):
        xtplus = alpha * x[i] + np.random.randn()
        x[i+1] = xtplus
    plt.plot(x)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 200
alpha = 0.9
x = np.empty(200)
x[0] = 0

for i in range(T-1):
    xtplus = alpha * x[i] + np.random.randn()
    x[i+1] = xtplus

plt.plot(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 200
alpha = 0.9
x = np.empty(200)
x[0] = 0

for i in range(T-1):
    xtplus = alpha * np.abs(x[i]) + np.random.randn()
    x[i+1] = xtplus

plt.plot(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 200
alpha = 0.9
x = np.empty(200)
x[0] = 0

for i in range(T-1):
    if x[i] > 0:
        xtplus = alpha * x[i] + np.random.randn()
    else:
        xtplus = -1 * alpha * x[i] + np.random.randn()
    x[i+1] = xtplus

plt.plot(x)
plt.show()

# %%
n = 100000

count = 0
for i in range(n):
    u, v = np.random.uniform(), np.random.uniform()
    d = np.sqrt((u - 0.5)**2 + (v - 0.5)**2)
    if d < 0.5:
        count += 1

area_estimate = count / n

print(area_estimate * 4)
# Out:
# 3.14152
